# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier

from sklearn.model_selection import (
    train_test_split,
    GridSearchCV,
    StratifiedKFold
)

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    classification_report
)

import matplotlib.pyplot as plt
import seaborn as sns

# %%
X_train = pd.read_csv("../data/processed/X_train_smote.csv")
X_test = pd.read_csv("../data/processed/X_test.csv")

y_train = pd.read_csv("../data/processed/y_train_smote.csv").squeeze()
y_test = pd.read_csv("../data/processed/y_test.csv").squeeze()

# %%
X_sample, _, y_sample, _ = train_test_split(
    X_train,
    y_train,
    train_size=20000,
    stratify=y_train,
    random_state=42
)

# %%
rf = RandomForestClassifier(
    random_state=42,
    class_weight="balanced"
)

# %%
param_grid = {
    "n_estimators": [100, 200],
    "max_depth": [10, 20, None],
    "min_samples_split": [2, 5],
    "min_samples_leaf": [1, 2],
    "max_features": ["sqrt"]
}

# %%
cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

# %%
grid_search = GridSearchCV(
    estimator=rf,
    param_grid=param_grid,
    scoring="f1",
    cv=cv,
    n_jobs=-1,
    verbose=2
)

grid_search.fit(X_sample, y_sample)
# Out:
# Fitting 5 folds for each of 24 candidates, totalling 120 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=42),
#              n_jobs=-1,
#              param_grid={'max_depth': [10, 20, None], 'max_features': ['sqrt'],
#                          'min_samples_leaf': [1, 2],
#                          'min_samples_split': [2, 5],
#                          'n_estimators': [100, 200]},
#              scoring='f1', verbose=2)

# %%
print("Best Parameters:")
print(grid_search.best_params_)

print("\nBest Cross Validation F1-score:")
print(round(grid_search.best_score_,4))
# Out:
# Best Parameters:
# {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
#
# Best Cross Validation F1-score:
# 0.8798

# %%
best_rf = RandomForestClassifier(
    **grid_search.best_params_,
    random_state=42
)

best_rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(max_depth=20, n_estimators=200, random_state=42)

# %%
y_pred = best_rf.predict(X_test)

y_prob = best_rf.predict_proba(X_test)[:,1]

# %%
accuracy = accuracy_score(y_test, y_pred)

precision = precision_score(y_test, y_pred)

recall = recall_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred)

roc_auc = roc_auc_score(y_test, y_prob)

print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1-score : {f1:.4f}")
print(f"ROC-AUC  : {roc_auc:.4f}")
# Out:
# Accuracy : 0.8541
# Precision: 0.2558
# Recall   : 0.1344
# F1-score : 0.1762
# ROC-AUC  : 0.7053

# %%
cm = confusion_matrix(y_test,y_pred)

plt.figure(figsize=(6,5))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues"
)

plt.title("Random Forest Confusion Matrix")

plt.xlabel("Predicted")

plt.ylabel("Actual")

plt.show()

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.95      0.92     45139
#            1       0.26      0.13      0.18      5931
#
#     accuracy                           0.85     51070
#    macro avg       0.57      0.54      0.55     51070
# weighted avg       0.82      0.85      0.83     51070

# %%
feature_importance = pd.DataFrame({
    "Feature": X_train.columns,
    "Importance": best_rf.feature_importances_
})

feature_importance = feature_importance.sort_values(
    by="Importance",
    ascending=False
)

feature_importance.head(10)
# Out:
#                   Feature  Importance
# 0                     Age    0.094273
# 6            InterestRate    0.071479
# 23        HasCoSigner_Yes    0.054558
# 1                  Income    0.054021
# 18      HasDependents_Yes    0.053751
# 4          MonthsEmployed    0.048717
# 15  MaritalStatus_Married    0.048709
# 2              LoanAmount    0.046299
# 7                LoanTerm    0.045523
# 11          Education_PhD    0.044028

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    data=feature_importance.head(10),
    x="Importance",
    y="Feature"
)

plt.title("Top 10 Important Features")

plt.xlabel("Importance")

plt.ylabel("Feature")

plt.show()

# %%
rf_results = pd.DataFrame({
    "Model": ["Random Forest"],
    "Accuracy": [accuracy],
    "Precision": [precision],
    "Recall": [recall],
    "F1 Score": [f1],
    "ROC-AUC": [roc_auc]
})

rf_results
# Out:
#            Model  Accuracy  Precision    Recall  F1 Score   ROC-AUC
# 0  Random Forest  0.854063   0.255777  0.134379  0.176191  0.705292

# %%
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'max_depth': 20, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}
# 0.8797916117843382

# %%
rf_results.to_csv("../results/rf_results.csv", index=False)
