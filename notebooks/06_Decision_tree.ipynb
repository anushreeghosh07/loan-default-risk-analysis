# %%
import pandas as pd
import numpy as np

from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import (
    train_test_split,
    GridSearchCV,
    StratifiedKFold
)

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    classification_report
)
from sklearn.model_selection import (
    train_test_split,
    GridSearchCV,
    StratifiedKFold
)

import matplotlib.pyplot as plt
import seaborn as sns

# %%
X_train = pd.read_csv("../data/processed/X_train_smote.csv")
X_test = pd.read_csv("../data/processed/X_test.csv")

y_train = pd.read_csv("../data/processed/y_train_smote.csv").squeeze()
y_test = pd.read_csv("../data/processed/y_test.csv").squeeze()

# %%
X_sample, _, y_sample, _ = train_test_split(
    X_train,
    y_train,
    train_size=20000,
    stratify=y_train,
    random_state=42
)

# %%
dt = DecisionTreeClassifier(random_state=42)

# %%
param_grid = {
    "criterion": ["gini", "entropy"],
    "max_depth": [5, 10, 15, 20],
    "min_samples_split": [2, 5, 10],
    "min_samples_leaf": [1, 2, 5]
}

# %%
cv = StratifiedKFold(
    n_splits=5,
    shuffle=True,
    random_state=42
)

# %%
grid_search = GridSearchCV(
    estimator=dt,
    param_grid=param_grid,
    scoring="f1",
    cv=cv,
    n_jobs=-1,
    verbose=2
)

grid_search.fit(X_sample, y_sample)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=42, shuffle=True),
#              estimator=DecisionTreeClassifier(random_state=42), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [5, 10, 15, 20],
#                          'min_samples_leaf': [1, 2, 5],
#                          'min_samples_split': [2, 5, 10]},
#              scoring='f1', verbose=2)

# %%
print("Best Parameters:")
print(grid_search.best_params_)

print("\nBest Cross-Validation F1-score:")
print(round(grid_search.best_score_, 4))
# Out:
# Best Parameters:
# {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
#
# Best Cross-Validation F1-score:
# 0.7948

# %%
best_dt = DecisionTreeClassifier(
    **grid_search.best_params_,
    random_state=42
)

best_dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=10, min_samples_leaf=5,
#                        random_state=42)

# %%
y_pred = best_dt.predict(X_test)
y_prob = best_dt.predict_proba(X_test)[:, 1]

# %%
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)
roc_auc = roc_auc_score(y_test, y_prob)

print(f"Accuracy : {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall   : {recall:.4f}")
print(f"F1-score : {f1:.4f}")
print(f"ROC-AUC  : {roc_auc:.4f}")
# Out:
# Accuracy : 0.7747
# Precision: 0.1920
# Recall   : 0.2929
# F1-score : 0.2319
# ROC-AUC  : 0.6548

# %%
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(6, 5))

sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues"
)

plt.title("Decision Tree Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")

plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.84      0.87     45139
#            1       0.19      0.29      0.23      5931
#
#     accuracy                           0.77     51070
#    macro avg       0.55      0.57      0.55     51070
# weighted avg       0.82      0.77      0.79     51070

# %%
feature_importance = pd.DataFrame({
    "Feature": X_train.columns,
    "Importance": best_dt.feature_importances_
})

feature_importance = feature_importance.sort_values(
    by="Importance",
    ascending=False
)

feature_importance.head(10)
# Out:
#                   Feature  Importance
# 0                     Age    0.156037
# 23        HasCoSigner_Yes    0.124178
# 18      HasDependents_Yes    0.107427
# 16   MaritalStatus_Single    0.097576
# 9   Education_High School    0.083053
# 15  MaritalStatus_Married    0.076457
# 10     Education_Master's    0.065603
# 11          Education_PhD    0.056652
# 17        HasMortgage_Yes    0.052254
# 6            InterestRate    0.051218

# %%
plt.figure(figsize=(10, 6))

sns.barplot(
    data=feature_importance.head(10),
    x="Importance",
    y="Feature"
)

plt.title("Top 10 Important Features")
plt.xlabel("Importance")
plt.ylabel("Feature")

plt.show()

# %%
dt_results = pd.DataFrame({
    "Model": ["Decision Tree"],
    "Accuracy": [accuracy],
    "Precision": [precision],
    "Recall": [recall],
    "F1 Score": [f1],
    "ROC-AUC": [roc_auc]
})

dt_results
# Out:
#            Model  Accuracy  Precision    Recall  F1 Score  ROC-AUC
# 0  Decision Tree  0.774701   0.191955  0.292868  0.231909  0.65475

# %%
print(grid_search.best_params_)
print(grid_search.best_score_)
# Out:
# {'criterion': 'entropy', 'max_depth': 10, 'min_samples_leaf': 5, 'min_samples_split': 2}
# 0.7948085619203372

# %%
dt_results.to_csv("../results/dt_results.csv", index=False)
